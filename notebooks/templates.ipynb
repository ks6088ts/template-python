# %% [markdown]
# # Templates

# %%
# !uv run python ../scripts/template.py --help
# Out:
#
#  Usage: template.py [OPTIONS] COMMAND [ARGS]...
#
#  template-python CLI
#
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │ --verbose  -v        Enable verbose output                                   │
# │ --help               Show this message and exit.                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Commands ───────────────────────────────────────────────────────────────────╮
# │ hello                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
# !uv run python ../scripts/template.py --verbose hello
# Out:
# 2026-05-10 15:35:41,381 [CRITICAL] Critical: Hello World (core.py:10)
# CRITICAL:template_python.core:Critical: Hello World
# 2026-05-10 15:35:41,381 [   ERROR] Error: Hello World (core.py:11)
# ERROR:template_python.core:Error: Hello World
# 2026-05-10 15:35:41,381 [ WARNING] Warning: Hello World (core.py:12)
# WARNING:template_python.core:Warning: Hello World
# 2026-05-10 15:35:41,381 [    INFO] Info: Hello World (core.py:13)
# INFO:template_python.core:Info: Hello World
# 2026-05-10 15:35:41,381 [   DEBUG] This is a debug message with name: World (template.py:47)
# DEBUG:__main__:This is a debug message with name: World
# 2026-05-10 15:35:41,381 [    INFO] Settings from .env: {
#   "project_name": "default-project",
#   "project_log_level": "INFO"
# } (template.py:48)
# INFO:__main__:Settings from .env: {
#   "project_name": "default-project",
#   "project_log_level": "INFO"
# }
